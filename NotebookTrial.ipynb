# %% [markdown]
# Hi folks! Are we able to do the report and the script in the same place? Can we have the explainer and real script be the same thing?

# %% [markdown]
# Someone smell like they ain't shower in a while
